# %% [markdown]
# # Geocoding missing schools

# %%
# my usual imports and setups
import pylab as pl
import pandas as pd
import numpy as np
#imports downloader

import scipy.stats
import geopy 
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut


# %pylab inline

import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Read in data

# %%
ref = 'MissingSchoolsForRevGeo.csv'

# %%
df = pd.read_csv(ref)

# %%
df.head()
# Out:
#    Unnamed: 0     DBN                  SCHNAM
# 0           0  00M801           HUNTER SCHOOL
# 1           1  00M802           HUNTER SCHOOL
# 2           2  00M803           HUNTER SCHOOL
# 3           6  01M022  GUSTAVE STRAUBENMULLER
# 4           7  01M025             MARTA VALLE

# %%
df.rename(columns = {'Unnamed: 0':"MasterIndex"}, inplace = True)

# %%
df.columns
# Out:
# Index([u'MasterIndex', u'DBN', u'SCHNAM'], dtype='object')

# %%
df.shape
# Out:
# (695, 3)

# %%
UniqueSchools = df.drop_duplicates([u'SCHNAM']).reset_index()

# %%
UniqueSchools.shape
# Out:
# (606, 4)

# %%
UniqueSchools['Latitude'] = np.nan
UniqueSchools['Longitude'] = np.nan

# %% [markdown]
# Let's find the school coordinates using a reverse geocode technique.

# %%
geolocator = Nominatim()

# %%
def do_geocode(address):
    try:
        return geolocator.geocode(address)
    except GeocoderTimedOut:
        return do_geocode(address)

# %%
# # ANDREW - DON'T WORRY ABOUT RUNNING THIS PART
# for i in range(UniqueSchools.shape[0]):
    
#     #location = geolocator.geocode(UniqueSchools[u'SCHNAM'][i])   
#     location = do_geocode(UniqueSchools[u'SCHNAM'][i])   
        
   
 #    if location is not None:
#         UniqueSchools['Latitude'][i] = location.latitude
#         UniqueSchools['Longitude'][i] = location.longitude
#     else:
#         UniqueSchools['Latitude'][i] = 'Missing'
#         UniqueSchools['Longitude'][i] = 'Missing'
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# GeocoderServiceErrorTraceback (most recent call last)
# <ipython-input-25-a8b6e00d0139> in <module>()
#       4
#       5     #location = geolocator.geocode(UniqueSchools[u'SCHNAM'][i])
# ----> 6     location = do_geocode(UniqueSchools[u'SCHNAM'][i])
#       7
#       8
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# ...
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
# ----> 5         return do_geocode(address)
#
# <ipython-input-24-d330849e8c9d> in do_geocode(address)
#       1 def do_geocode(address):
#       2     try:
# ----> 3         return geolocator.geocode(address)
#       4     except GeocoderTimedOut:
#       5         return do_geocode(address)
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python2/lib/python2.7/site-packages/geopy/geocoders/osm.pyc in geocode(self, query, exactly_one, timeout, addressdetails, language, geometry)
#     190         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     191         return self._parse_json(
# --> 192             self._call_geocoder(url, timeout=timeout), exactly_one
#     193         )
#     194
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python2/lib/python2.7/site-packages/geopy/geocoders/base.pyc in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     158                 if "timed out" in message:
#     159                     raise GeocoderTimedOut('Service timed out')
# --> 160             raise GeocoderServiceError(message)
#     161
#     162         if hasattr(page, 'getcode'):
#
# GeocoderServiceError: maximum recursion depth exceeded while calling a Python object

# %%
# # ANDREW - DON'T WORRY ABOUT RUNNING THIS PART
#UniqueSchools.to_csv('UniqueSchoolsLoc.csv', sep=',')

# %%
UniqueSchools2 = UniqueSchools.iloc[257:]

# %%
## Run from index 257 onwards

UniqueSchools2.index
# Out:
# RangeIndex(start=257, stop=606, step=1)

# %%
for i in UniqueSchools2.index:
    
    location = geolocator.geocode(UniqueSchools[u'SCHNAM'][i])   
    #location = do_geocode(UniqueSchools[u'SCHNAM'][i])   
        
   
    if location is not None:
        UniqueSchools['Latitude'][i] = location.latitude
        UniqueSchools['Longitude'][i] = location.longitude
    else:
        UniqueSchools['Latitude'][i] = 'Missing'
        UniqueSchools['Longitude'][i] = 'Missing'
# Out:
# GeocoderTimedOutTraceback (most recent call last)
# <ipython-input-34-4b347f96e57f> in <module>()
#       2 for i in UniqueSchools2.index:
#       3
# ----> 4     location = geolocator.geocode(UniqueSchools[u'SCHNAM'][i])
#       5     #location = do_geocode(UniqueSchools[u'SCHNAM'][i])
#       6
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python2/lib/python2.7/site-packages/geopy/geocoders/osm.pyc in geocode(self, query, exactly_one, timeout, addressdetails, language, geometry)
#     190         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     191         return self._parse_json(
# --> 192             self._call_geocoder(url, timeout=timeout), exactly_one
#     193         )
#     194
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python2/lib/python2.7/site-packages/geopy/geocoders/base.pyc in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     157             elif isinstance(error, SSLError):
#     158                 if "timed out" in message:
# --> 159                     raise GeocoderTimedOut('Service timed out')
#     160             raise GeocoderServiceError(message)
#     161
#
# GeocoderTimedOut: Service timed out

# %%
UniqueSchools2.to_csv('UniqueSchoolsLoc2.csv', sep=',')
