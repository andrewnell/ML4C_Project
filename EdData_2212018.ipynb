# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/baileygriswold/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ### Quality Review Rating

# %%
df = pd.read_excel('QualityReviewRatings_20052017.xlsx')

# %%
df.head(50)
# Out:
#                        Rating Key        O  \
# NaN  NaN                      NaN       WD
#      NaN                      NaN        P
#      NaN                      NaN        D
#      NaN                      NaN      UPF
#      NaN                      NaN  U or UD
#      NaN                      NaN      NaN
# BN   SchYR              StartDate  Overall
# M307 SY05-06  2006-04-03 00:00:00        P
# M459 SY05-06  2006-04-03 00:00:00        P
# M560 SY05-06  2006-04-03 00:00:00       WD
# M294 SY05-06  2006-04-05 00:00:00       WD
# M299 SY05-06  2006-04-05 00:00:00        P
# M407 SY05-06  2006-04-05 00:00:00       WD
# M519 SY05-06  2006-04-05 00:00:00       WD
# M304 SY05-06  2006-04-07 00:00:00        P
# M449 SY05-06  2006-04-07 00:00:00       WD
# M570 SY05-06  2006-04-07 00:00:00        P
# M696 SY05-06  2006-04-07 00:00:00       WD
# K544 SY05-06  2006-04-10 00:00:00        P
# K337 SY05-06  2006-04-24 00:00:00        P
# K685 SY05-06  2006-04-24 00:00:00       WD
# ...

# %%
df.reset_index(inplace=True)

# %%
df.rename(columns=(df.loc[6]), inplace = True)

# %%
df.head(10)
# Out:
#      BN    SchYR            StartDate  Overall  \
# 0   NaN      NaN                  NaN       WD
# 1   NaN      NaN                  NaN        P
# 2   NaN      NaN                  NaN        D
# 3   NaN      NaN                  NaN      UPF
# 4   NaN      NaN                  NaN  U or UD
# 5   NaN      NaN                  NaN      NaN
# 6    BN    SchYR            StartDate  Overall
# 7  M307  SY05-06  2006-04-03 00:00:00        P
# 8  M459  SY05-06  2006-04-03 00:00:00        P
# 9  M560  SY05-06  2006-04-03 00:00:00       WD
#
#                                                QS1_1  QS1_2  QS1_3  QS1_4  \
# 0                                     Well Developed    NaN    NaN    NaN
# 1                                         Proficient    NaN    NaN    NaN
# 2                                         Developing    NaN    NaN    NaN
# 3  Underdeveloped with Proficient Features (only ...    NaN    NaN    NaN
# ...

# %%
df = df[7:]

# %%
df.columns
# Out:
# Index(['BN', 'SchYR', 'StartDate', 'Overall', 'QS1_1', 'QS1_2', 'QS1_3',
#        'QS1_4', 'QS1_5', 'QS1_6', 'QS1_7', 'QSOverall1', 'QS2_1', 'QS2_2',
#        'QS2_3', 'QS2_4', 'QS2_5', 'QS2_6', 'QS2_7', 'QSOverall2', 'QS3_1',
#        'QS3_2', 'QS3_3', 'QS3_4', 'QS3_5', 'QS3_6', 'QS3_7', 'QS3_8',
#        'QSOverall3', 'QS4_1', 'QS4_2', 'QS4_3', 'QS4_4', 'QS4_5', 'QS4_6',
#        'QS4_7', 'QSOverall4', 'QS5_1', 'QS5_2', 'QS5_3', 'QS5_4', 'QS5_5',
#        'QS5_6', 'QS5_7', 'QSOverall5'],
#       dtype='object')

# %%
df.drop(['QS1_1', 'QS1_2', 'QS1_3',
       'QS1_4', 'QS1_5', 'QS1_6', 'QS1_7', 'QS2_1', 'QS2_2',
       'QS2_3', 'QS2_4', 'QS2_5', 'QS2_6', 'QS2_7', 'QS3_1',
       'QS3_2', 'QS3_3', 'QS3_4', 'QS3_5', 'QS3_6', 'QS3_7', 'QS3_8',
       'QS4_1', 'QS4_2', 'QS4_3', 'QS4_4', 'QS4_5', 'QS4_6',
       'QS4_7',  'QS5_1', 'QS5_2', 'QS5_3', 'QS5_4', 'QS5_5',
       'QS5_6', 'QS5_7'],axis=1, inplace=True)
# Out:
# /Users/baileygriswold/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
df.head()
# Out:
#       BN    SchYR            StartDate Overall QSOverall1 QSOverall2  \
# 7   M307  SY05-06  2006-04-03 00:00:00       P          P         WD
# 8   M459  SY05-06  2006-04-03 00:00:00       P          P          P
# 9   M560  SY05-06  2006-04-03 00:00:00      WD         WD         WD
# 10  M294  SY05-06  2006-04-05 00:00:00      WD         WD         WD
# 11  M299  SY05-06  2006-04-05 00:00:00       P          P          P
#
#    QSOverall3 QSOverall4 QSOverall5
# 7          WD         WD          P
# 8          WD          P          P
# 9          WD         WD         WD
# 10         WD         WD          P
# 11          P          P          P

# %%
df['Overall'].value_counts().plot(kind='bar')

# %% [markdown]
# D is bad -- developing, U is also bad (underdeveloped), UPF is underdeveloped w proficient features

# %% [markdown]
# ### School Survey Data

# %%
df = pd.read_excel('2016_2017_EMS_SQR_Results.xlsx')
df.head()
# Out:
#       DBN                     School Name School Type  Enrollment  \
# 0  01M015       P.S. 015 Roberto Clemente  Elementary         161
# 1  01M019             P.S. 019 Asher Levy  Elementary         247
# 2  01M020            P.S. 020 Anna Silver  Elementary         499
# 3  01M034  P.S. 034 Franklin D. Roosevelt         K-8         337
# 4  01M063       The STAR Academy - P.S.63  Elementary         178
#
#   Rigorous Instruction Rating Collaborative Teachers Rating  \
# 0            Exceeding Target              Exceeding Target
# 1            Exceeding Target              Exceeding Target
# 2          Not Meeting Target            Approaching Target
# 3          Approaching Target            Approaching Target
# 4            Exceeding Target              Exceeding Target
#
#   Supportive Environment Rating Effective School Leadership Rating  \
# 0              Exceeding Target                   Exceeding Target
# 1                Meeting Target                   Exceeding Target
# ...

# %%
df.columns
# Out:
# Index(['DBN', 'School Name', 'School Type', 'Enrollment',
#        'Rigorous Instruction Rating', 'Collaborative Teachers Rating',
#        'Supportive Environment Rating', 'Effective School Leadership Rating',
#        'Strong Family-Community Ties Rating', 'Trust Rating',
#        'Student Achievement Rating', 'Rigorous Instruction - Percent Positive',
#        'Collaborative Teachers - Percent Positive',
#        'Supportive Environment - Percent Positive',
#        'Effective School Leadership - Percent Positive',
#        'Strong Family-Community Ties - Percent Positive',
#        'Trust - Percent Positive',
#        'Quality Review - How interesting and challenging is the curriculum?',
#        'Quality Review - How effective is the teaching and learning?',
#        'Quality Review - How well does the school assess what students are learning?',
#        'Quality Review - How clearly are high expectations communicated to students and staff?',
# ...

# %%
pd.tools.plotting.scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='hist')
# Out:
# /Users/baileygriswold/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12089a630>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ee7de10>]], dtype=object)

# %%
df['Economic Need Index'].hist()

# %%
pl.plot(df['Percent of teachers with 3 or more years of experience'], df['Average Incoming ELA Proficiency (Based on 4th Grade)'], 'o')

# %%
df['Student Achievement Rating'].value_counts(dropna=False).plot(kind='bar')

# %%
df['Teacher Attendance Rate'].hist()

# %%
df['Teacher Attendance Rate'].value_counts(dropna=False).plot(kind='bar')

# %%
df['Teacher Attendance Rate'].value_counts()
# Out:
# 0.964    62
# 0.961    59
# 0.965    48
# 0.966    47
# 0.967    45
# 0.962    42
# 0.968    42
# 0.971    41
# 0.959    41
# 0.963    40
# 0.958    40
# 0.956    38
# 0.960    38
# 0.955    37
# 0.957    36
# 0.969    36
# 0.972    35
# 0.970    35
# 0.973    33
# 0.974    27
# 0.954    21
# 0.951    19
# 0.977    19
# 0.975    18
# 0.952    16
# 0.976    16
# 0.950    14
# 0.979    13
# 0.953    13
# 0.978    11
#          ..
# 0.982     8
# 0.949     7
# 0.980     7
# 0.943     6
# 0.985     5
# 0.945     4
# 0.989     3
# 0.986     3
# 0.944     3
# 0.931     3
# 0.940     3
# 0.988     3
# 0.993     3
# 0.983     2
# 0.990     1
# 0.995     1
# 0.934     1
# 0.987     1
# 0.936     1
# 0.939     1
# 0.991     1
# 0.935     1
# 0.994     1
# 0.930     1
# 0.997     1
# 0.938     1
# 0.917     1
# 0.922     1
# 0.927     1
# 1.000     1
# Name: Teacher Attendance Rate, Length: 65, dtype: int64

# %%
pl.plot(df['Percent of teachers with 3 or more years of experience'], df['Economic Need Index'], 'o')

# %%
colors = {'Not Meeting Target':'red', 'Exceeding Target':'green', 'Approaching Target':'orange', 'Meeting Target':'blue', np.nan:'gray'}

fig, ax = plt.subplots()

X = df['Percent of teachers with 3 or more years of experience']
Y = df['Economic Need Index']

ax.scatter(X, Y, c=df['Student Achievement Rating'].apply(lambda x: colors[x]))

# %% [markdown]
# - random forest -- school quality classification
# - looking at a specific district -- qualititative statements
# - anomamlous schools -- what's the x factor
# - renewal schools -- how did they change over time?
# - Compare between charter and public schools?
# - comparisons between and within districts
# - how likey are you to go to an underperforming/police active school based on demographics/location?
# - PTA and distribuiton of equity in schools? funding amounts by PTA?
