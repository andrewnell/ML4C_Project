# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import pylab as pl


# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Jonathan\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
#Usual packages for import

from __future__ import print_function, division
import pylab as pl
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.lines as mlines
import matplotlib.pyplot as plt
import time
from IPython.display import display, clear_output
from scipy.cluster.hierarchy import dendrogram, linkage
#import sklearn.clusterEC
from scipy.cluster.vq import whiten

from scipy import cluster
#from geopy.distance import great_circle
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster as scp

from scipy.spatial.distance import cdist, pdist

from sklearn.cluster import KMeans
from scipy.cluster.vq import kmeans2


# url handlers

import ast
import urllib.request
from io import StringIO
import os
import zipfile

try:
    #Packages for Python 3
    from urllib.parse import urlencode
    from urllib.request import urlopen
    from urllib.error import HTTPError
    
except ImportError:
    #Packages for Python 2
    from urllib import urlencode
    from urllib2 import urlopen, HTTPError
    
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO

#from geopy.geocoders import Nominatim
#import geopandas as gp

import scipy.stats
import seaborn as sns
import statsmodels.api as sm
plt.style.use('seaborn')

# %pylab inline

## additional imports (although I'm not sure I ended up using them)
#import choroplethNYC as cp
#import categoricalcolorbar as ccb
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('../01 Data/schma19962016.csv')
df.head()
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (124,125,126,148,149,150,183,220,221,222,226,227,230,231,232,234,235,247) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       DBN            SCHNAM  YEAR  SCHLEV  SCHLEV5  SCHS219962016    XDBN  \
# 0  00M801     HUNTER SCHOOL  1996     NaN      NaN            NaN  00M801
# 1  00M802     HUNTER SCHOOL  1996     NaN      NaN            NaN  00M802
# 2  00M803     HUNTER SCHOOL  1996     NaN      NaN            NaN  00M803
# 3  01M015  ROBERTO CLEMENTE  1996     NaN      NaN            NaN  01M015
# 4  01M019        ASHER LEVY  1996     NaN      NaN            NaN  01M019
#
#    XDBN_FLAG  ENRNUMPRK  ENRNUMKID   ...    BNLONG_YRFIRST  BNLONG_YRLAST  \
# 0          0         16         48   ...              1996           1998
# 1          0          0          0   ...              1996           1998
# 2          0          0          0   ...              1996           1998
# 3          0          0         36   ...              1996           2016
# 4          0         33         82   ...              1996           2016
#
#    BNLONG_TOTALYRS  BNLONG_PHASEDOUT19962016  BNLONG_PHASEDIN19962016  \
# 0              3.0                         1                        0
# 1              3.0                         1                        0
# 2              3.0                         1                        0
# 3             21.0                         0                        0
# 4             21.0                         0                        0
#
#    BNLONG_CONTOPERATE19962016  CBO  HSJHS  HSSCHSAMP2  SPECHS
# 0                           0    0    NaN           6       0
# 1                           0    0    1.0           6       0
# 2                           0    0    0.0           6       0
# 3                           0    0    NaN           6       0
# 4                           0    0    NaN           6       0
#
# [5 rows x 270 columns]

# %%
df.shape
# Out:
# (30345, 270)

# %%
df['BNLONG_CONTOPERATE19962016'].value_counts(dropna=False)
# Out:
# 0    30345
# Name: BNLONG_CONTOPERATE19962016, dtype: int64

# %%
#highest year for BN number -- when a school was closed?
df['BNLONG_YRLAST'].value_counts(dropna=False)
# Out:
# 2016    26658
# 2015      965
# 2014      436
# 2007      255
# 2011      239
# 2006      230
# 2010      195
# 2009      169
# 2005      167
# 2008      160
# 2004      150
# 2012      130
# 2002      124
# 2001      115
# 2013      114
# 2003       94
# 2000       51
# 1998       35
# 1999       32
# ...       ...                                                ...   ...
# 28673  79X695                                   PASSAGES ACADEMY  2015
# 28792  02M473                             WASHINGTON IRVING YABC  2016
# 28814  02M575  MANHATTAN COMPREHENSIVE NIGHT AND DAY HIGH SCHOOL  2016
# 28975  06M457                             GEORGE WASHINGTON YABC  2016
# 29016  07X456                        ALFRED E. SMITH CAMPUS YABC  2016
# 29075  08X408                             HERBERT H. LEHMAN YABC  2016
# 29081  08X507                                     STEVENSON YABC  2016
# 29242  10X503                                        WALTON YABC  2016
# 29243  10X504                                       KENNEDY YABC  2016
# 29249  10X668                         DEWITT CLINTON CAMPUS YABC  2016
# 29296  11X417                                 C COLUMBUS HS YABC  2016
# 29354  12X428            LEARNING TO WORK YABC AT MONROE ACADEMY  2016
# 29409  13K657                             DOWNTOWN BROOKLYN YABC  2016
# 29454  14K923                        AUTOMOTIVE HIGH SCHOOL YABC  2016
# 29534  16K959                                BOYS AND GIRLS YABC  2016
# 29566  17K467                                       ERASMUS YABC  2016
# 29623  18K922               SOUTH SHORE EDUCATIONAL COMPLEX YABC  2016
# 29653  19K431                              THOMAS JEFFERSON YABC  2016
# 29655  19K501                       FRANKLIN K. LANE CAMPUS YABC  2016
# 29715  20K658                     FRANKLIN DELANO ROOSEVELT YABC  2016
# 29753  21K411                               ABRAHAM LINCOLN YABC  2016
# 29881  24Q457                          H.S. ARTS & BUSINESS YABC  2016
# 29932  25Q467                                      FLUSHING YABC  2016
# 30031  27Q487                                    JOHN ADAMS YABC  2016
# 30253  31R607                                 STATEN ISLAND YABC  2016
# 30340  79M973                                    RESTART ACADEMY  2016
# 30341  79M984                                               LYFE  2016
# 30342  79Q344                                 EAST RIVER ACADEMY  2016
# 30343  79Q950                             PATHWAYS TO GRADUATION  2016
# 30344  79X695                                   PASSAGES ACADEMY  2016
#
#        SCHLEV  SCHLEV5  SCHS219962016    XDBN  XDBN_FLAG  ENRNUMPRK  \
# 1108      NaN      NaN            NaN  79K409          0          0
# 1109      NaN      NaN            NaN  79K510          0          0
# 1110      NaN      NaN            NaN  79K511          0          0
# 1111      NaN      NaN            NaN  79K512          0          0
# 1112      NaN      NaN            NaN  79K565          0          0
# 1113      NaN      NaN            NaN  79K573          0          0
# 1114      NaN      NaN            NaN  79K580          0          0
# 1115      NaN      NaN            NaN  79K591          0          0
# 1116      NaN      NaN            NaN  79K665          0          0
# 1117      NaN      NaN            NaN  79K931          0          0
# 1118      NaN      NaN            NaN  79K932          0          0
# 1119      NaN      NaN            NaN  79M469          0          0
# 1120      NaN      NaN            NaN  79M479          0          0
# 1121      NaN      NaN            NaN  79M500          0          0
# 1122      NaN      NaN            NaN  79M501          0          0
# 1123      NaN      NaN            NaN  79M502          0          0
# 1124      NaN      NaN            NaN  79M510          0          0
# 1125      NaN      NaN            NaN  79M530          0          0
# 1126      NaN      NaN            NaN  79M573          0          0
# 1127      NaN      NaN            NaN  79M585          0          0
# 1128      NaN      NaN            NaN  79M590          0          0
# 1129      NaN      NaN            NaN  79M591          0          0
# 1109                            0    0    NaN           4       0
# 1110                            0    0    0.0           4       0
# 1111                            0    0    0.0           4       0
# 1112                            0    0    0.0           4       0
# 1113                            0    0    0.0           4       0
# 1114                            0    0    0.0           4       0
# 1115                            0    0    0.0           4       0
# 1116                            0    0    0.0           4       0
# 1117                            0    0    0.0           4       0
# 1118                            0    0    0.0           4       0
# 1119                            0    0    0.0           4       0
# 1120                            0    0    0.0           4       0
# 1121                            0    0    0.0           4       0
# 1122                            0    0    0.0           4       0
# 1123                            0    0    0.0           4       0
# 1124                            0    0    NaN           4       0
# 1125                            0    0    0.0           4       0
# 1126                            0    0    0.0           4       0
# 1127                            0    0    0.0           4       0
# 1128                            0    0    0.0           4       0
# 1129                            0    0    0.0           4       0
# 1130                            0    0    0.0           4       0
# 1131                            0    0    0.0           4       0
# 1132                            0    0    0.0           4       0
# 1133                            0    0    0.0           4       0
# 1134                            0    0    NaN           4       0
# 1135                            0    0    0.0           4       0
# 1136                            0    0    0.0           4       0
# 1137                            0    0    0.0           4       0
# ...                           ...  ...    ...         ...     ...
# 28673                           0    0    0.0           4       0
# 28792                           0    0    NaN           4       0
# 28814                           0    0    0.0           4       0
# 28975                           0    0    NaN           4       0
# 29016                           0    0    NaN           4       0
# 29075                           0    0    NaN           4       0
# 29081                           0    0    NaN           4       0
# 29242                           0    0    NaN           4       0
# 29243                           0    0    NaN           4       0
# 29249                           0    0    NaN           4       0
# 29296                           0    0    NaN           4       0
# 29354                           0    0    NaN           4       0
# 29409                           0    0    NaN           4       0
# 29454                           0    0    NaN           4       0
# 29534                           0    0    NaN           4       0
# 29566                           0    0    NaN           4       0
# 29623                           0    0    NaN           4       0
# 29653                           0    0    NaN           4       0
# 29655                           0    0    NaN           4       0
# 29715                           0    0    NaN           4       0
# 29753                           0    0    NaN           4       0
# 29881                           0    0    NaN           4       0
# 29932                           0    0    NaN           4       0
# 30031                           0    0    NaN           4       0
# 30253                           0    0    NaN           4       0
# 30340                           0    0    0.0           4       0
# 30341                           0    0    NaN           4       0
# 30342                           0    0    0.0           4       0
# 30343                           0    0    NaN           4       0
# 30344                           0    0    0.0           4       0
#
# [925 rows x 270 columns]

# %%
df.LCGSTAT.value_counts(dropna=False)
# Out:
# OPEN      19689
# NaN       10632
# CLOSED       24
# Name: LCGSTAT, dtype: int64

# %% [markdown]
# # Feature engineering

# %%
df_feats = pd.read_csv('../01 Data/schma features of interest.csv')
df_feats.head()
# Out:
#    Feat_Code          Feat_expl Notes
# 0  ATTPCTG01  School attendnace   NaN
# 1  ATTPCTG02  School attendnace   NaN
# 2  ATTPCTG03  School attendnace   NaN
# 3  ATTPCTG04  School attendnace   NaN
# 4  ATTPCTG05  School attendnace   NaN

# %%
codes = df_feats.Feat_Code

# %%
keep = df.columns[df.columns.isin(codes)]

# %%
keep = list(keep)

# %%
for x in ['DBN','SCHNAM','YEAR','BNLONG']:
    keep.append(x)

# %%
df.shape
# Out:
# (30345, 270)

# %%
df[keep].shape
# Out:
# (30345, 146)

# %%
#keeping only the features of interest
df = df[keep]

# %%
df_feats.sort_values(by='Notes').head(20)
# Out:
#            Feat_Code                                          Feat_expl  \
# 16      CCDENRNUMFRL  CCD: NUMBER STUDENTS ELIGIBLE FOR THE FREE OR ...
# 17         CCDNUMFTE                      CCD: CLASSROOM TEACHERS (FTE)
# 100          LCGSTAT                                  open close status
# 89     HPGPERDIP4AVG         HS PROG RPT: 4-YEAR DIPLOMA RATE (AVERAGE)
# 88   HPGGENREGREMAVG  HS PROG RPT: COMPLETION RATE FOR REMAINING REG...
# 87   HPGGEN10CYR3AVG  HS PROG RPT: % 3RD YEAR GEN STUDENTS EARNING 1...
# 90     HPGPERDIP6AVG         HS PROG RPT: 6-YEAR RATE DIPLOMA (AVERAGE)
# 85   HPGGEN10CYR1AVG  HS PROG RPT: % 1ST YEAR GEN STUDENTS EARNING 1...
# 84        HPGG08PROF         HS PROG RPT: AVERAGE 8TH GRADE PROFICIENCY
# 86   HPGGEN10CYR2AVG  HS PROG RPT: % 2ND YEAR GEN STUDENTS EARNING 1...
# 82         ENRNUMTOT                                   TOTAL enrollment
# 99         LCGSCHTYP                                       school type
# 133  STCELAPCTL34G08  ELA STATE TEST, NYC: PERCENT AT LEVEL THREE OR...
# 128  STCELAPCTL34G03  ELA STATE TEST, NYC: PERCENT AT LEVEL THREE OR...
# 129  STCELAPCTL34G04  ELA STATE TEST, NYC: PERCENT AT LEVEL THREE OR...
# 130  STCELAPCTL34G05  ELA STATE TEST, NYC: PERCENT AT LEVEL THREE OR...
# 131  STCELAPCTL34G06  ELA STATE TEST, NYC: PERCENT AT LEVEL THREE OR...
# 132  STCELAPCTL34G07  ELA STATE TEST, NYC: PERCENT AT LEVEL THREE OR...
# 134  STCELAPCTL34TOT  ELA STATE TEST, NYC: PERCENT AT LEVEL THREE OR...
# 0          ATTPCTG01                                  School attendnace
#
#                                                  Notes
# 16                                  *need to normalize
# 17                                *normalize by no stu
# 100                                 24 noted as closed
# 89                                   CAN BE AN OUTCOME
# 88                                   CAN BE AN OUTCOME
# 87                                   CAN BE AN OUTCOME
# 90                                   CAN BE AN OUTCOME
# 85                                   CAN BE AN OUTCOME
# 84                                   CAN BE AN OUTCOME
# 86                                   CAN BE AN OUTCOME
# 82                                    TOTAL enrollment
# 99   drop everything that isn't a general academic ...
# 133  feature for clustering, but outcome for classi...
# 128  feature for clustering, but outcome for classi...
# 129  feature for clustering, but outcome for classi...
# 130  feature for clustering, but outcome for classi...
# 131  feature for clustering, but outcome for classi...
# 132  feature for clustering, but outcome for classi...
# 134  feature for clustering, but outcome for classi...
# 0                                                  NaN

# %%
df['CCDNUMFTE_normd'] = (df['CCDNUMFTE'] / df['ENRNUMTOT'])

# %%
df['CCDENRNUMFRL_normd'] = (df['CCDENRNUMFRL'] / df['ENRNUMTOT'])

# %%
df['LCGSCHTYP'].value_counts(dropna=False).index
# Out:
# Index([ 'GENERAL ACADEMIC',                 nan,                 'S',
#        'SPECIAL EDUCATION',   'TRANSFER SCHOOL',       'ALTERNATIVE',
#         'CAREER TECHNICAL',       'HOME SCHOOL',              'YABC',
#        'SUSPENSION CENTER',                 'P',                'FC',
#                        'I',    'NOT APPLICABLE',       'BUDGET ONLY',
#                    'ADULT'],
#       dtype='object')

# %% [markdown]
# YABC = young adult burrough center\

# %%
len(df[df['LCGSCHTYP'].isin(['HOME SCHOOL','YABC',
       'SUSPENSION CENTER', 'FC',  'P',
             'BUDGET ONLY', 'NOT APPLICABLE','I',
                   'ADULT'])])
# Out:
# 78

# %%
#dropping alt school types
df = df[~df['LCGSCHTYP'].isin(['HOME SCHOOL','YABC',
       'SUSPENSION CENTER', 'FC',  'P',
             'BUDGET ONLY', 'NOT APPLICABLE','I',
                   'ADULT'])]

# %%
df.shape
# Out:
# (30267, 148)

# %%
df.isnull().sum(axis=1).sort_values(ascending=False)
# Out:
# 3864     124
# 4408     124
# 4334     124
# 4300     124
# 4246     124
# 4211     124
# 4175     124
# 4140     124
# 4104     124
# 4082     124
# 4045     124
# 4029     124
# 3996     124
# 3963     124
# 3932     124
# 3900     124
# 3809     124
# 3770     124
# 3737     124
# 3709     124
# 3679     124
# 3658     124
# 3630     124
# 3602     124
# 3534     124
# 4364     124
# 4265     124
# 4441     124
# 4508     124
# 4567     124
#         ...
# 14362     31
# 15770     31
# 16561     31
# 15878     31
# 16110     31
# 15877     31
# 16410     31
# 16717     31
# 11056     28
# 25332     28
# 16379     26
# 12523     25
# 26895     25
# 14021     24
# 23675     23
# 17932     22
# 11399     20
# 18796     19
# 18649     19
# 25195     19
# 22039     17
# 20408     17
# 23535     17
# 20259     17
# 21895     17
# 17213     17
# 15526     16
# 17069     15
# 14161     14
# 15673     14
# Length: 30267, dtype: int64

# %%
#check nans
df.isnull().sum().sort_values(ascending=False)
# Out:
# CLSAVGG12          30108
# CLSNUMG12          30097
# HSOPCTHSGTOT       28923
# HSOPCTSENTOT       28923
# HSOPCTDRPTOT       28923
# HSOPCTDCHTOT       28885
# HPGPERDIP6AVG      28331
# HPGG08PROF         28307
# HPGPERDIP4AVG      27928
# HPGGENREGREMAVG    27804
# HPGGEN10CYR3AVG    27795
# HPGGEN10CYR2AVG    27708
# HPGGEN10CYR1AVG    27638
# ENRNUMELL          26998
# ENRNUMPOV          26998
# ENRNUMOTH          26998
# HSOPCTDRPNYC       26033
# HSOPCTSENNYC       26033
# HSOPCTHSGNYC       26033
# CLSAVGGEN          25824
# CLSAVGG11          24218
# CLSNUMG11          24217
# ATTPCTG12          24104
# CLSNUMG10          23885
# CLSAVGG10          23885
# ATTPCTG11          23745
# STCELAPCTL34G07    23376
# CLSAVGG09          23364
# STCMTHPCTL34G08    23363
# CLSNUMG09          23362
#                    ...
# SCHLOGRD            2349
# ATTPCTTOT           1844
# CLSAVGTOT           1026
# CLSNUMTOT           1026
# SCHGRDCONFIG         955
# SCHNAM               688
# BNLONG               636
# ENRNUMG08              0
# ENRNUMPRK              0
# ENRNUMKID              0
# ENRNUMG01              0
# ENRNUMG02              0
# ENRNUMG03              0
# ENRNUMG04              0
# ENRNUMG05              0
# ENRNUMG06              0
# ENRNUMG07              0
# ENRNUMG10              0
# ENRNUMG09              0
# YEAR                   0
# ENRNUMG11              0
# ENRNUMG12              0
# ENRNUMOHS              0
# ENRNUMSPD              0
# ENRNUMTOT              0
# CBO                    0
# SPECHS                 0
# DBN                    0
# ENRNUMGEN              0
# CTMSCH                 0
# Length: 148, dtype: int64

# %% [markdown]
# # Question: predicting school closures

# %%
df['LCGSTAT'].value_counts(dropna=False)
# Out:
# OPEN      19619
# NaN       10624
# CLOSED       24
# Name: LCGSTAT, dtype: int64

# %%
df[df['LCGSTAT'] == 'CLOSED']
# Out:
#        SCHLEV  SCHLEV5  ENRNUMPRK  ENRNUMKID  ENRNUMG01  ENRNUMG02  ENRNUMG03  \
# 9872      2.0      2.0          0          0          0          0          0
# 9873      2.0      2.0          0          0          0          0          0
# 9875      1.0      1.0          0         85         63         59          0
# 10017     1.0      1.0          6         13         17         45         39
# 10052     2.0      2.0          0          0          0          0          0
# 10073     1.0      1.0          0        105         94         94        100
# 10101     2.0      2.0          0          0          0          0          0
# 10131     1.0      1.0          0        102        128        113        116
# 10251     1.0      1.0          0        192        100          0          0
# 10454     2.0      2.0          0          0          0          0          0
# 10464     2.0      2.0          0          0          0          0          0
# 10468     1.0      1.0          0          0          0          0          0
# 10472     2.0      2.0          0          0          0          0          0
# 10595     2.0      2.0          0          0          0          0          0
# 10663     2.0      2.0          0          0          0          0          0
# 10734     2.0      2.0          0          0          0          0          0
# 10921     2.0      2.0          0          0          0          0          0
# 11167     3.0      3.0          0          0          0          0          0
# 11168    10.0      4.0          0          0          0          0          0
# 11173     8.0      4.0          0          0          0          0          0
# 11181     8.0      4.0          0          0          0          0          0
# 11183     8.0      4.0          0          0          0          0          0
# 14812     2.0      2.0          0          0          0          0          0
# 14943     2.0      2.0          0          0          0          0          0
#
#        ENRNUMG04  ENRNUMG05  ENRNUMG06         ...          DMGPCTELLTOT  \
# 9872           0          0          0         ...                   NaN
# 9873           0          0          0         ...                   NaN
# 9875           0          0         47         ...                   NaN
# 10017         49         47         44         ...                   NaN
# 10052         35         54         56         ...                   NaN
# 10073         97         71         37         ...                   NaN
# 10101          0          0          0         ...                   NaN
# 10131        132        105          0         ...                   NaN
# 10251          0          0          0         ...                   NaN
# 10454          0          0        110         ...                   NaN
# 10464          0          0         60         ...                   NaN
# 10468          0          0        132         ...                   NaN
# 10472          0          0         70         ...                   NaN
# 10595          0          0         53         ...                   NaN
# 10663          0          0         76         ...                   NaN
# 10734          0          0          0         ...                   NaN
# 10921          0          0          0         ...                   NaN
# 11167          0          0          0         ...                   NaN
# 11168          0          0          0         ...                   NaN
# 11173          0          0          0         ...                   NaN
# 11181          0          0          0         ...                   NaN
# 11183          0          0          0         ...                   NaN
# 14812          0          0          0         ...              3.703704
# 14943          0          0          0         ...              3.720930
#
#        CTMSCH  CBO  SPECHS     DBN                          SCHNAM  YEAR  \
# 9872        0    0       0  01M450  EAST SIDE COMMUNITY HIGH SCHOO  2004
# 9873        0    0       0  01M509  CMSP CHANCELLOR'S MODEL SCHOOL  2004
# 9875        0    0       0  01M539                          NEST+M  2004
# 10017       0    0       0  04M109        HOSTOS ACADEMY AT JHS99M  2004
# 10052       0    0       0  05M469         CHOIR ACADEMY OF HARLEM  2004
# 10073       0    0       0  06M176    W. HAYWOOD BURNS SCHOOL #176  2004
# 10101       0    0       0  07X149     ELIJAH D. CLARK - JHS # 149  2004
# 10131       0    0       0  08X060        GEORGE L. GALLEGO SCHOOL  2004
# 10251       0    0       0  10X257           THE CHILDREN'S SCHOOL  2004
# 10454       0    0       0  15K142      STRANAHAN IS (RENAMED 378)  2004
# 10464       0    0       0  15K429  THE BROOKLYN SCHOOL FOR GLOBAL  2004
# 10468       0    0       0  15K448                             NaN  2004
# 10472       0    0       0  15K496  THE SCHOOL FOR INTERNATIONAL S  2004
# 10595       0    0       0  19K409    EAST NEW YORK FAMILY ACADEMY  2004
# 10663       0    0       0  21K280  BROOKLYN STUDIO SECONDARY SCH.  2004
# 10734       0    0       0  23K696     TEACHERS PREPARATORY SCHOOL  2004
# 10921       0    0       0  28Q680                  QUEENS GATEWAY  2004
# 11167       0    0       0  76K460            JOHN JAY HIGH SCHOOL  2004
# 11168       0    0       0  76K497  THE SCHOOL FOR INTERNATIONAL S  2004
# 11173       0    0       0  79K512               BUSHWICK OUTREACH  2004
# 11181       0    0       0  79M502        LOWER MANHATTAN OUTREACH  2004
# 11183       0    0       0  79M530                   PROJECT BLEND  2004
# 14812       0    0       0  14K033            JHS 033 MARK HOPKINS  2007
# 14943       0    0       0  17K390        M S 390 MAGGIE L. WALKER  2007
#
#        BNLONG  CCDNUMFTE_normd  CCDENRNUMFRL_normd
# 9872     M450         0.160377                 NaN
# 9873      NaN         0.178417                 NaN
# 9875     M539         0.147239                 NaN
# 10017    M109         0.030508                 NaN
# 10052    M469         0.108614                 NaN
# 10073    M176         0.035397                 NaN
# 10101    X149         0.103067                 NaN
# 10131    X060              NaN                 NaN
# 10251    X257         0.080906                 NaN
# 10454    K142         0.018248                 NaN
# 10464    K429         0.172589                 NaN
# 10468    K448         0.082742                 NaN
# 10472    K496              NaN                 NaN
# 10595    K409         0.195804                 NaN
# 10663    K280         0.089712                 NaN
# 10734    K696              NaN                 NaN
# 10921    Q680         0.158470                 NaN
# 11167    K460              NaN                 NaN
# 11168    K497              NaN                 NaN
# 11173    K512              NaN                 NaN
# 11181    M502              NaN                 NaN
# 11183    M530              NaN                 NaN
# 14812    K033              NaN                 NaN
# 14943    K390         0.145116            0.944186
#
# [24 rows x 148 columns]

# %%
df[df['BNLONG'] == 'M450']
# Out:
#        SCHLEV  SCHLEV5  ENRNUMPRK  ENRNUMKID  ENRNUMG01  ENRNUMG02  ENRNUMG03  \
# 21        NaN      NaN          0          0          0          0          0
# 1175      NaN      NaN          0          0          0          0          0
# 2346      NaN      NaN          0          0          0          0          0
# 3530      NaN      NaN          0          0          0          0          0
# 4752      2.0      2.0          0          0          0          0          0
# 6018      2.0      2.0          0          0          0          0          0
# 7290      2.0      2.0          0          0          0          0          0
# 8568      2.0      2.0          0          0          0          0          0
# 9872      2.0      2.0          0          0          0          0          0
# 11228     2.0      2.0          0          0          0          0          0
# 12675     2.0      2.0          0          0          0          0          0
# 14158     2.0      2.0          0          0          0          0          0
# 15670     2.0      2.0          0          0          0          0          0
# 17210     2.0      2.0          0          0          0          0          0
# 18793     2.0      2.0          0          0          0          0          0
# 20404     2.0      2.0          0          0          0          0          0
# 22035     2.0      2.0          0          0          0          0          0
# 23671     2.0      2.0          0          0          0          0          0
# 25328     2.0      2.0          0          0          0          0          0
# 27029     2.0      2.0          0          0          0          0          0
# 28697     2.0      2.0          0          0          0          0          0
#
#        ENRNUMG04  ENRNUMG05  ENRNUMG06         ...          DMGPCTELLTOT  \
# 21             0          0          0         ...                   NaN
# 1175           0          0          0         ...                   NaN
# 2346           0          0          0         ...                   NaN
# 3530           0          0          0         ...                   NaN
# 4752           0          0          0         ...                   NaN
# 6018           0          0          0         ...                   NaN
# 7290           0          0          0         ...                   NaN
# 8568           0          0          0         ...                   NaN
# 9872           0          0          0         ...                   NaN
# 11228          0          0          0         ...                   NaN
# 12675          0          0          0         ...              5.988024
# 14158          0          0         48         ...              4.982206
# 15670          0          0         51         ...              6.317689
# 17210          0          0         49         ...              4.945055
# 18793          0          0         53         ...              6.618962
# 20404          0          0         58         ...              7.011686
# 22035          0          0         71         ...              5.000000
# 23671          0          0         70         ...                   NaN
# 25328          0          0         68         ...                   NaN
# 27029          0          0         81         ...                   NaN
# 28697          0          0         70         ...                   NaN
#
#        CTMSCH  CBO  SPECHS     DBN                          SCHNAM  YEAR  \
# 21          0    0       0  01M450  EAST SIDE COMMUNITY HIGH SCHOO  1996
# 1175        0    0       0  01M450  EAST SIDE COMMUNITY HIGH SCHOO  1997
# 2346        0    0       0  01M450  EAST SIDE COMMUNITY HIGH SCHOO  1998
# 3530        1    0       0  01M450  EAST SIDE COMMUNITY HIGH SCHOO  1999
# 4752        0    0       0  01M450  EAST SIDE COMMUNITY HIGH SCHOO  2000
# 6018        0    0       0  01M450  EAST SIDE COMMUNITY HIGH SCHOO  2001
# 7290        0    0       0  01M450  EAST SIDE COMMUNITY HIGH SCHOO  2002
# 8568        0    0       0  01M450  EAST SIDE COMMUNITY HIGH SCHOO  2003
# 9872        0    0       0  01M450  EAST SIDE COMMUNITY HIGH SCHOO  2004
# 11228       1    0       0  01M450  EAST SIDE COMMUNITY HIGH SCHOO  2005
# 12675       0    0       0  01M450  EAST SIDE COMMUNITY HIGH SCHOO  2006
# 14158       0    0       0  01M450      EAST SIDE COMMUNITY SCHOOL  2007
# 15670       1    0       0  01M450      EAST SIDE COMMUNITY SCHOOL  2008
# 17210       0    0       0  01M450      EAST SIDE COMMUNITY SCHOOL  2009
# 18793       0    0       0  01M450      EAST SIDE COMMUNITY SCHOOL  2010
# 20404       1    0       0  01M450      EAST SIDE COMMUNITY SCHOOL  2011
# 22035       1    0       0  01M450      EAST SIDE COMMUNITY SCHOOL  2012
# 23671       0    0       0  01M450      EAST SIDE COMMUNITY SCHOOL  2013
# 25328       1    0       0  01M450      EAST SIDE COMMUNITY SCHOOL  2014
# 27029       1    0       0  01M450      EAST SIDE COMMUNITY SCHOOL  2015
# 28697       0    0       0  01M450      EAST SIDE COMMUNITY SCHOOL  2016
#
#        BNLONG  CCDNUMFTE_normd  CCDENRNUMFRL_normd
# 21       M450              NaN                 NaN
# 1175     M450              NaN                 NaN
# 2346     M450              NaN                 NaN
# 3530     M450              NaN                 NaN
# 4752     M450              NaN                 NaN
# 6018     M450              NaN                 NaN
# 7290     M450              NaN                 NaN
# 8568     M450              NaN                 NaN
# 9872     M450         0.160377                 NaN
# 11228    M450         0.066798            0.000000
# 12675    M450         0.067864            0.796407
# 14158    M450         0.074199            0.709964
# 15670    M450         0.076173            0.788809
# 17210    M450         0.076740            0.793040
# 18793    M450         0.076208                 NaN
# 20404    M450         0.072037            0.816361
# 22035    M450         0.076003            0.792642
# 23671    M450              NaN                 NaN
# 25328    M450              NaN                 NaN
# 27029    M450              NaN                 NaN
# 28697    M450              NaN                 NaN
#
# [21 rows x 148 columns]

# %%
dff = pd.melt(df, id_vars=['BNLONG', 'YEAR'])#.pivot(index='BNLONG', columns='YEAR')

# %%
dff.head()
# Out:
#   BNLONG  YEAR variable value
# 0   M801  1996   SCHLEV   NaN
# 1   M802  1996   SCHLEV   NaN
# 2   M803  1996   SCHLEV   NaN
# 3   M015  1996   SCHLEV   NaN
# 4   M019  1996   SCHLEV   NaN

# %%
f1 = dff.groupby(["BNLONG",'variable', "YEAR"])['value'].aggregate(lambda x: x).unstack().reset_index()
f1.columns=f1.columns.tolist()

# %%
f1.shape
# Out:
# (291416, 23)

# %%
f1 = f1[~(f1.isnull().sum(axis=1) >= 21)]

# %%
f1
# Out:
#        BNLONG      variable     1996     1997     1998     1999     2000  \
# 0        K001     ATTPCTG01    88.76    92.53    90.76    91.04    91.62
# 1        K001     ATTPCTG02    91.33    91.37    92.66       92    92.26
# 2        K001     ATTPCTG03    92.43    93.11    92.36    93.55     92.9
# 3        K001     ATTPCTG04    92.36    93.75    92.44    91.88    93.99
# 4        K001     ATTPCTG05    93.04    92.92    92.61     93.2    92.07
# 12       K001     ATTPCTKID    89.73    90.98    89.44    89.96    90.36
# 13       K001     ATTPCTPRK     79.9    86.19    87.09    84.75    85.54
# 14       K001     ATTPCTTOT    90.36    91.97    91.28    91.39    91.57
# 15       K001           CBO        0        0        0        0        0
# 20       K001     CLSAVGG01  25.5385       30       27  30.1429     24.8
# 21       K001     CLSAVGG02  30.5455       27       29  26.2857  33.2857
# 22       K001     CLSAVGG03  28.4444  35.5556  26.9091     33.8  30.1667
# 23       K001     CLSAVGG04       32  27.7778  30.6667     22.4    40.75
# 32       K001     CLSAVGGEN  30.5806  31.6129  30.5588  29.0833      NaN
# 33       K001     CLSAVGKID       27       26  27.8571   19.875  15.8462
# 34       K001     CLSAVGOHS      NaN      NaN      NaN      NaN      NaN
# 35       K001     CLSAVGPRK    17.75       18       18    18.75       18
# 36       K001     CLSAVGSPD     12.5    12.75       13     12.5        9
# 37       K001     CLSAVGTOT  28.5143  29.4571  29.5833  28.2105   26.125
# 38       K001     CLSNUMG01      6.5        6        7        7       10
# 39       K001     CLSNUMG02      5.5        6        6        7        7
# 40       K001     CLSNUMG03      4.5      4.5      5.5        5        6
# 41       K001     CLSNUMG04      4.5      4.5      4.5        5        4
# 50       K001     CLSNUMGEN       31       31       34       36       46
# 51       K001     CLSNUMKID        6        6        7        8       13
# 52       K001     CLSNUMOHS      NaN      NaN      NaN      NaN      NaN
# 53       K001     CLSNUMPRK        4        4        4        4        6
# 54       K001     CLSNUMSPD        4        4        2        2        2
# 55       K001     CLSNUMTOT       35       35       36       38       48
# 56       K001        CTMSCH        0        0        0        0        0
# ...       ...           ...      ...      ...      ...      ...      ...
# 291331   X966     ENRNUMASI     None     None     None     None     None
# 291333   X966     ENRNUMFEM     None     None     None     None     None
# 291334   X966     ENRNUMG01     None     None     None     None     None
# 291335   X966     ENRNUMG02     None     None     None     None     None
# 291336   X966     ENRNUMG03     None     None     None     None     None
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## Remove rows where any NaN
tsBlackEnrolment.dropna(axis=0, how='any',inplace=True)
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tsBlackEnrolment.head()
# Out:
#     BNLONG   variable 2000 2001 2002  2003  2004 2005 2006 2007 2008 2009  \
# 59    K001  ENRNUMAFM   45   33   30    28    23   21   20   29   20   18
# 205   K002  ENRNUMAFM  917  919  989  1162  1060  880  674  537  441  369
# 351   K003  ENRNUMAFM  861  842  752   674   651  542  566  542  517  495
# 497   K004  ENRNUMAFM  153  171  166   175   178  207  201  212  193  212
# 643   K005  ENRNUMAFM  639  629  629   608   581  472  430  396  364  344
#
#     2010 2011 2012 2013 2014 2015 2016
# 59    16   27   22   18   19   12   10
# 205  332  341  373  397  406  391  384
# 351  527  503  483  430  388  358  306
# 497  224  224  223  223  221  212  215
# 643  375  361  328  296  246  210  184

# %%
# new dictionary colUpdate with all column names as strings
colUpdate = { 2000 : u'2000',
              2001 : u'2001',     
              2002 : u'2002',
              2003 : u'2003',     
              2004 : u'2004',
              2005 : u'2005',
              2006 : u'2006',
              2007 : u'2007',     
              2008 : u'2008',
              2009 : u'2009',     
              2010 : u'2010',
              2011 : u'2011',
              2012 : u'2012',
              2013 : u'2013', 
              2014 : u'2014',
              2015 : u'2015',
              2016 : u'2016'}
tsBlackEnrolment.rename(columns = colUpdate, inplace=True)
tsBlackEnrolment.columns
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\pandas\core\frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# Index(['BNLONG', 'variable', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016'],
#       dtype='object')

# %%
tsBlackEnrolment['popmean'] = tsBlackEnrolment['2016']
tsBlackEnrolment['stdev'] = tsBlackEnrolment['2016']
tsBlackEnrolment.head()
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     BNLONG   variable 2000 2001 2002  2003  2004 2005 2006 2007  ...  2009  \
# 59    K001  ENRNUMAFM   45   33   30    28    23   21   20   29  ...    18
# 205   K002  ENRNUMAFM  917  919  989  1162  1060  880  674  537  ...   369
# 351   K003  ENRNUMAFM  861  842  752   674   651  542  566  542  ...   495
# 497   K004  ENRNUMAFM  153  171  166   175   178  207  201  212  ...   212
# 643   K005  ENRNUMAFM  639  629  629   608   581  472  430  396  ...   344
#
#     2010 2011 2012 2013 2014 2015 2016 popmean stdev
# 59    16   27   22   18   19   12   10      10    10
# 205  332  341  373  397  406  391  384     384   384
# 351  527  503  483  430  388  358  306     306   306
# 497  224  224  223  223  221  212  215     215   215
# 643  375  361  328  296  246  210  184     184   184
#
# [5 rows x 21 columns]

# %%
# append on mean and standard deviation to the datasets (BRUTE FORCE)

# Calculate the mean and standard deviation of the school totals over time
## in preparation for clustering
tsBlackEnrolment['popmean'] = tsBlackEnrolment['2016']
tsBlackEnrolment['stdev'] = tsBlackEnrolment['2016']

for i in tsBlackEnrolment.index:
    tsBlackEnrolment['popmean'].loc[i] = tsBlackEnrolment.loc[i].drop(['BNLONG', 'variable','popmean','stdev']).mean() 
    tsBlackEnrolment['stdev'].loc[i] = tsBlackEnrolment.loc[i].drop(['BNLONG', 'variable','popmean','stdev']).std()
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Jonathan\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
tsBlackEnrolment.shape
# Out:
# (991, 21)

# %%
## Standardise the data

tsBlackEnrolment.columns
# Out:
# Index(['BNLONG', 'variable', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', 'popmean', 'stdev'],
#       dtype='object')

# %%
tsBlackEnrolStandard = tsBlackEnrolment.copy()
columnsStandard = ['2000', '2001', '2002', '2003', '2004', '2005',
                   '2006', '2007', '2008', '2009', '2010', '2011', 
                   '2012', '2013', '2014', '2015', '2016']

# %%
for i in columnsStandard:
    tsBlackEnrolStandard[i] = (tsBlackEnrolment[i] - tsBlackEnrolment.popmean) / tsBlackEnrolment.stdev

# %%
tsBlackEnrolStandard.columns
# Out:
# Index(['BNLONG', 'variable', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', 'popmean', 'stdev'],
#       dtype='object')

# %%
vals = tsBlackEnrolStandard.drop(['BNLONG', 'variable', 'popmean', 'stdev'], axis = 1)

# %%
# Check if as expected, means are zero and standard devations are 1

print("Expect means of each row to be = 0\n", vals.mean(1)[:10])
print("Expect stds of each row to be = 1\n", vals.std(1)[:10])
# Out:
# Expect means of each row to be = 0
#  59      0.000000e+00
# 205    -5.224579e-17
# 351    -3.918434e-17
# 497    -2.089832e-16
# 643    -5.224579e-17
# 789    -4.702121e-16
# 935    -2.089832e-16
# 1081    3.265362e-17
# 1227    6.530724e-17
# 1373   -3.836800e-17
# dtype: float64
# Expect stds of each row to be = 1
#  59      1.0
# 205     1.0
# 351     1.0
# 497     1.0
# 643     1.0
# 789     1.0
# 935     1.0
# 1081    1.0
# 1227    1.0
# 1373    1.0
# dtype: float64

# %%
## Adapted code from Applied Data Science course for 'elbow' output

def elbow(data,K):
#data is your input as numpy form
#K is a list of number of clusters you would like to show.
    # Run the KMeans model and save all the results for each number of clusters
    KM = [KMeans(n_clusters=k).fit(data) for k in K]
    
    # Save the centroids for each model with a increasing k
    centroids = [k.cluster_centers_ for k in KM]

    # For each k, get the distance between the data with each center. 
    D_k = [cdist(data, cent, 'euclidean') for cent in centroids]
    
    # But we only need the distance to the nearest centroid since we only calculate dist(x,ci) for its own cluster.
    globals()['dist'] = [np.min(D,axis=1) for D in D_k]
    
    # Calculate the Average SSE.
    avgWithinSS = [sum(d)/data.shape[0] for d in dist]
    
    
    # elbow curve
    fig = plt.figure(figsize = (10,5))
    ax = fig.add_subplot(111)
    ax.plot(K, avgWithinSS, 'g*-', markersize = 10)
    plt.grid(True)
    pl.xticks(fontsize = 14)
    pl.yticks(fontsize = 14)
    plt.xlabel('Number of clusters', fontsize = 16)
    plt.ylabel('Average within-cluster sum of squares', fontsize = 16)
    plt.title('Elbow for KMeans clustering', fontsize = 20)
    plt.tight_layout()
    plt.show()
    
    
    # Total with-in sum of square plot. Another way to show the result.
    wcss = [sum(d**2) for d in dist]
    tss = sum(pdist(data)**2)/data.shape[0]
    bss = tss-wcss
    
    fig = plt.figure(figsize = (10,5))
    ax = fig.add_subplot(111)
    ax.plot(K, bss/tss*100, 'g*-',  markersize = 10)
    plt.grid(True)
    pl.xticks(fontsize = 14)
    pl.yticks(fontsize = 14)
    plt.xlabel('Number of clusters', fontsize = 16)
    plt.ylabel('Percentage of variance explained', fontsize = 16)
    plt.title('Elbow for KMeans clustering', fontsize = 20)
    plt.tight_layout()
    plt.show()

# %%
vals = tsBlackEnrolStandard[columnsStandard]

# %%
elbow(vals, range(1,26))

# %% [markdown]
# Fit 5 clusters

# %%
###############################################################################
# Fit K-means algorithm for selected number of clusters (again)


#creating a date range: 2000-2016
timeline = pd.date_range('2000', '2017', freq='A')

nc = 5

km = KMeans(n_clusters=nc, random_state=888)

km.fit(vals)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=888, tol=0.0001, verbose=0)

# %%
fig = pl.figure(figsize=(12, 8))
for i, Xc in enumerate(km.cluster_centers_):
    ax = fig.add_subplot(3, 2, (i + 1))
    ax.plot(timeline, Xc, lw = 8, alpha = 0.5, c='IndianRed')
    
    pl.title("Cluster centre %d"%(i), fontsize = 16)
    
    
    pl.xticks(fontsize = 15, rotation=75)
    ax.set_yticklabels(['' * len(ax.get_xticklabels())])
    plt.tight_layout()
print("Cluster centers")
# Out:
# Cluster centers

# %%
tsBlackEnrolStandard['ClustLabel'] = km.labels_

# %%
tsBlackEnrolStandard.columns
# Out:
# Index(['BNLONG', 'variable', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', 'popmean', 'stdev', 'ClustLabel'],
#       dtype='object')

# %%
vals = tsBlackEnrolStandard.drop(['variable', 'popmean', 'stdev'], axis = 1)

# %%
for j in range(nc):
    print("Schools in cluster", j)
    print(list(vals.BNLONG[km.labels_ == j]))
    print("\n")

#clustersdf = gp.GeoDataFrame()
#clustersdf['precinct'] = vals.PCT
#clustersdf['cluster'] = km.labels_
# Out:
# Schools in cluster 0
# ['K011', 'K088', 'K127', 'K131', 'K132', 'K133', 'K152', 'K153', 'K157', 'K169', 'K196', 'K199', 'K229', 'K231', 'K372', 'M034', 'M057', 'M063', 'M072', 'M094', 'M098', 'M169', 'M223', 'M226', 'M250', 'M258', 'M411', 'M468', 'M515', 'Q009', 'Q011', 'Q018', 'Q036', 'Q046', 'Q048', 'Q073', 'Q075', 'Q079', 'Q084', 'Q094', 'Q097', 'Q107', 'Q108', 'Q130', 'Q149', 'Q159', 'Q162', 'Q163', 'Q166', 'Q169', 'Q176', 'Q182', 'Q185', 'Q190', 'Q191', 'Q200', 'Q203', 'Q213', 'Q217', 'Q221', 'Q235', 'Q550', 'R003', 'R005', 'R008', 'R037', 'R046', 'R048', 'R050', 'R055', 'R069', 'R605', 'X004', 'X023', 'X030', 'X037', 'X046', 'X049', 'X054', 'X055', 'X059', 'X062', 'X087', 'X109', 'X121', 'X150', 'X153', 'X157', 'X181', 'X186', 'X204', 'X205', 'X396', 'X495']
#
#
# Schools in cluster 1
 'Q201', 'Q220', 'Q232', 'Q250', 'Q460', 'Q499', 'Q575', 'Q670', 'Q680', 'Q811', 'Q993', 'R001', 'R025', 'R039', 'R041', 'R056', 'R080', 'R373', 'R450', 'R460', 'R721', 'X014', 'X017', 'X025', 'X029', 'X071', 'X114', 'X140', 'X168', 'X176', 'X182', 'X188', 'X195', 'X196', 'X212', 'X277', 'X327', 'X500', 'X505', 'X530', 'X550', 'X682', 'X684', 'X691', 'X811']
#
#
# Schools in cluster 4
# ['K017', 'K024', 'K029', 'K039', 'K041', 'K057', 'K061', 'K062', 'K068', 'K077', 'K078', 'K086', 'K089', 'K094', 'K096', 'K098', 'K099', 'K107', 'K114', 'K121', 'K136', 'K137', 'K139', 'K140', 'K145', 'K150', 'K160', 'K161', 'K190', 'K198', 'K209', 'K213', 'K225', 'K228', 'K234', 'K235', 'K240', 'K244', 'K246', 'K254', 'K255', 'K265', 'K267', 'K272', 'K274', 'K278', 'K281', 'K285', 'K289', 'K291', 'K298', 'K303', 'K308', 'K315', 'K321', 'K328', 'K340', 'K370', 'K371', 'K377', 'K383', 'K385', 'K394', 'K396', 'K397', 'K399', 'K445', 'K455', 'K485', 'K495', 'K540', 'K620', 'K660', 'M003', 'M006', 'M011', 'M015', 'M052', 'M054', 'M059', 'M075', 'M079', 'M084', 'M087', 'M089', 'M096', 'M104', 'M110', 'M115', 'M126', 'M134', 'M142', 'M152', 'M167', 'M183', 'M217', 'M225', 'M234', 'M242', 'M243', 'M289', 'M400', 'M407', 'M414', 'M420', 'M439', 'M495', 'M505', 'M528', 'M552', 'M570', 'M580', 'M605', 'M615', 'M625', 'M751', 'M811', 'Q005', 'Q031', 'Q033', 'Q047', 'Q056', 'Q069', 'Q070', 'Q074', 'Q077', 'Q087', 'Q101', 'Q106', 'Q109', 'Q114', 'Q117', 'Q118', 'Q120', 'Q135', 'Q141', 'Q144', 'Q150', 'Q153', 'Q156', 'Q165', 'Q173', 'Q175', 'Q181', 'Q188', 'Q196', 'Q205', 'Q216', 'Q219', 'Q226', 'Q227', 'Q229', 'Q233', 'Q238', 'Q251', 'Q400', 'Q415', 'Q430', 'Q440', 'Q445', 'Q450', 'Q455', 'Q492', 'Q494', 'Q495', 'Q496', 'Q505', 'Q600', 'Q620', 'R011', 'R013', 'R022', 'R024', 'R034', 'R036', 'R044', 'R049', 'R051', 'R052', 'R060', 'R061', 'R075', 'R440', 'X003', 'X008', 'X016', 'X019', 'X020', 'X021', 'X033', 'X035', 'X047', 'X048', 'X058', 'X072', 'X081', 'X085', 'X086', 'X088', 'X091', 'X092', 'X097', 'X100', 'X101', 'X108', 'X112', 'X117', 'X123', 'X125', 'X127', 'X129', 'X131', 'X138', 'X144', 'X151', 'X160', 'X162', 'X206', 'X211', 'X218', 'X219', 'X229', 'X236', 'X254', 'X279', 'X303', 'X339', 'X360', 'X390', 'X391', 'X455', 'X480', 'X600', 'X692', 'X754']

# %% [markdown]
# _______________

# %% [markdown]
# ## Hispanic student enrolment

# %%
tsHispanicEnrolment = f1[f1['variable']=='ENRNUMHIS']

# %%
tsHispanicEnrolment.head()
# Out:
#     BNLONG   variable 1996 1997 1998 1999  2000  2001  2002  2003  ...  2007  \
# 77    K001  ENRNUMHIS  NaN  NaN  NaN  NaN  1108  1155  1096  1092  ...   994
# 223   K002  ENRNUMHIS  NaN  NaN  NaN  NaN    79    72    81    99  ...    60
# 369   K003  ENRNUMHIS  NaN  NaN  NaN  NaN    29    32    30    33  ...    41
# 515   K004  ENRNUMHIS  NaN  NaN  NaN  NaN    62    58    58    48  ...    63
# 661   K005  ENRNUMHIS  NaN  NaN  NaN  NaN    50    50    56    65  ...    47
#
#      2008  2009  2010  2011  2012  2013  2014  2015  2016
# 77   1001  1015  1066  1084  1107  1146  1111  1115  1137
# 223    58    49    46    38    34    45    48    55    61
# 369    33    41    44    46    52    53    50    49    53
# 515    55    63    70    76    86    83    75    93    85
# 661    45    67    65    57    53    47    49    43    32
#
# [5 rows x 23 columns]

# %%
## Remove columns where all NaN
tsHispanicEnrolment.dropna(axis=1, how='all', inplace=True)
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## Remove rows where any NaN
tsHispanicEnrolment.dropna(axis=0, how='any',inplace=True)
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tsHispanicEnrolment.head()
# Out:
#     BNLONG   variable  2000  2001  2002  2003  2004  2005 2006 2007  2008  \
# 77    K001  ENRNUMHIS  1108  1155  1096  1092  1047  1004  982  994  1001
# 223   K002  ENRNUMHIS    79    72    81    99    94    68   63   60    58
# 369   K003  ENRNUMHIS    29    32    30    33    39    32   33   41    33
# 515   K004  ENRNUMHIS    62    58    58    48    51    67   62   63    55
# 661   K005  ENRNUMHIS    50    50    56    65    66    57   54   47    45
#
#      2009  2010  2011  2012  2013  2014  2015  2016
# 77   1015  1066  1084  1107  1146  1111  1115  1137
# 223    49    46    38    34    45    48    55    61
# 369    41    44    46    52    53    50    49    53
# 515    63    70    76    86    83    75    93    85
# 661    67    65    57    53    47    49    43    32

# %%
# new dictionary colUpdate with all column names as strings
colUpdate = { 2000 : u'2000',
              2001 : u'2001',     
              2002 : u'2002',
              2003 : u'2003',     
              2004 : u'2004',
              2005 : u'2005',
              2006 : u'2006',
              2007 : u'2007',     
              2008 : u'2008',
              2009 : u'2009',     
              2010 : u'2010',
              2011 : u'2011',
              2012 : u'2012',
              2013 : u'2013', 
              2014 : u'2014',
              2015 : u'2015',
              2016 : u'2016'}
tsHispanicEnrolment.rename(columns = colUpdate, inplace=True)
tsHispanicEnrolment.columns
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\pandas\core\frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# Index(['BNLONG', 'variable', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016'],
#       dtype='object')

# %%
tsHispanicEnrolment['popmean'] = tsHispanicEnrolment['2016']
tsHispanicEnrolment['stdev'] = tsHispanicEnrolment['2016']
tsHispanicEnrolment.head()
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     BNLONG   variable  2000  2001  2002  2003  2004  2005 2006 2007  ...   \
# 77    K001  ENRNUMHIS  1108  1155  1096  1092  1047  1004  982  994  ...
# 223   K002  ENRNUMHIS    79    72    81    99    94    68   63   60  ...
# 369   K003  ENRNUMHIS    29    32    30    33    39    32   33   41  ...
# 515   K004  ENRNUMHIS    62    58    58    48    51    67   62   63  ...
# 661   K005  ENRNUMHIS    50    50    56    65    66    57   54   47  ...
#
#      2009  2010  2011  2012  2013  2014  2015  2016 popmean stdev
# 77   1015  1066  1084  1107  1146  1111  1115  1137    1137  1137
# 223    49    46    38    34    45    48    55    61      61    61
# 369    41    44    46    52    53    50    49    53      53    53
# 515    63    70    76    86    83    75    93    85      85    85
# 661    67    65    57    53    47    49    43    32      32    32
#
# [5 rows x 21 columns]

# %%
# append on mean and standard deviation to the datasets (BRUTE FORCE)

# Calculate the mean and standard deviation of the school totals over time
## in preparation for clustering
tsHispanicEnrolment['popmean'] = tsHispanicEnrolment['2016']
tsHispanicEnrolment['stdev'] = tsHispanicEnrolment['2016']

for i in tsHispanicEnrolment.index:
    tsHispanicEnrolment['popmean'].loc[i] = tsHispanicEnrolment.loc[i].drop(['BNLONG', 'variable','popmean','stdev']).mean() 
    tsHispanicEnrolment['stdev'].loc[i] = tsHispanicEnrolment.loc[i].drop(['BNLONG', 'variable','popmean','stdev']).std()
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
tsHispanicEnrolment.shape
# Out:
# (991, 21)

# %%
## Standardise the data

tsHispanicEnrolment.columns
# Out:
# Index(['BNLONG', 'variable', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', 'popmean', 'stdev'],
#       dtype='object')

# %%
tsHispanicEnrolStandard = tsHispanicEnrolment.copy()
columnsStandard = ['2000', '2001', '2002', '2003', '2004', '2005',
                   '2006', '2007', '2008', '2009', '2010', '2011', 
                   '2012', '2013', '2014', '2015', '2016']

# %%
for i in columnsStandard:
    tsHispanicEnrolStandard[i] = (tsHispanicEnrolment[i] - tsHispanicEnrolment.popmean) / tsHispanicEnrolment.stdev

# %%
tsHispanicEnrolStandard.columns
# Out:
# Index(['BNLONG', 'variable', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', 'popmean', 'stdev'],
#       dtype='object')

# %%
vals = tsHispanicEnrolStandard.drop(['BNLONG', 'variable', 'popmean', 'stdev'], axis = 1)

# %%
# Check if as expected, means are zero and standard devations are 1

print("Expect means of each row to be = 0\n", vals.mean(1)[:10])
print("Expect stds of each row to be = 1\n", vals.std(1)[:10])
# Out:
# Expect means of each row to be = 0
#  77      1.880848e-15
# 223    -2.898009e-17
# 369     1.044916e-16
# 515     2.742904e-16
# 661     2.612289e-17
# 807    -1.175530e-16
# 953     3.265362e-17
# 1099    2.351061e-16
# 1245   -3.134747e-16
# 1391    3.591898e-16
# dtype: float64
# Expect stds of each row to be = 1
#  77      1.0
# 223     1.0
# 369     1.0
# 515     1.0
# 661     1.0
# 807     1.0
# 953     1.0
# 1099    1.0
# 1245    1.0
# 1391    1.0
# dtype: float64

# %%
vals = tsHispanicEnrolStandard[columnsStandard]

# %%
elbow(vals, range(1,26))

# %%
###############################################################################
# Fit K-means algorithm for selected number of clusters (again)


#creating a date range: 2000-2016
timeline = pd.date_range('2000', '2017', freq='A')

nc = 5

km = KMeans(n_clusters=nc, random_state=888)

km.fit(vals)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=888, tol=0.0001, verbose=0)

# %%
fig = pl.figure(figsize=(12, 8))
for i, Xc in enumerate(km.cluster_centers_):
    ax = fig.add_subplot(3, 2, (i + 1))
    ax.plot(timeline, Xc, lw = 8, alpha = 0.5, c='IndianRed')
    
    pl.title("Cluster centre %d"%(i), fontsize = 16)
    
    
    pl.xticks(fontsize = 15, rotation=75)
    ax.set_yticklabels(['' * len(ax.get_xticklabels())])
    plt.tight_layout()
print("Cluster centers")
# Out:
# Cluster centers

# %%
tsHispanicEnrolStandard['ClustLabel'] = km.labels_

# %%
tsHispanicEnrolStandard.columns
# Out:
# Index(['BNLONG', 'variable', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', 'popmean', 'stdev', 'ClustLabel'],
#       dtype='object')

# %%
vals = tsHispanicEnrolStandard.drop(['variable', 'popmean', 'stdev'], axis = 1)

# %%
for j in range(nc):
    print("Schools in cluster", j)
    print(list(vals.BNLONG[km.labels_ == j]))
    print("\n")
# Out:
# Schools in cluster 0
# ['K001', 'K009', 'K028', 'K036', 'K040', 'K045', 'K053', 'K065', 'K088', 'K098', 'K130', 'K131', 'K140', 'K157', 'K163', 'K184', 'K197', 'K199', 'K206', 'K212', 'K231', 'K236', 'K241', 'K253', 'K254', 'K257', 'K278', 'K282', 'K284', 'K307', 'K312', 'K315', 'K327', 'K340', 'K361', 'K368', 'K373', 'K376', 'K380', 'K383', 'K398', 'K430', 'M002', 'M092', 'M123', 'M169', 'M199', 'M247', 'M411', 'M485', 'M515', 'M575', 'Q005', 'Q011', 'Q013', 'Q015', 'Q021', 'Q022', 'Q026', 'Q031', 'Q051', 'Q054', 'Q060', 'Q078', 'Q082', 'Q089', 'Q095', 'Q107', 'Q108', 'Q114', 'Q130', 'Q141', 'Q144', 'Q146', 'Q149', 'Q152', 'Q157', 'Q159', 'Q166', 'Q169', 'Q173', 'Q176', 'Q177', 'Q181', 'Q182', 'Q190', 'Q191', 'Q193', 'Q196', 'Q201', 'Q203', 'Q205', 'Q221', 'Q223', 'Q251', 'Q256', 'Q492', 'Q498', 'Q752', 'R004', 'R038', 'R046', 'R049', 'R055', 'X005', 'X011', 'X016', 'X036', 'X056', 'X057', 'X063', 'X086', 'X089', 'X094', 'X103', 'X108', 'X109', 'X114', 'X140', 'X153', 'X157', 'X170', 'X181', 'X186', 'X204', 'X226', 'X279', 'X291', 'X396', 'X754']
#
#
# Schools in cluster 1
# ['K003', 'K004', 'K006', 'K007', 'K008', 'K011', 'K021', 'K030', 'K048', 'K052', 'K062', 'K077', 'K089', 'K090', 'K095', 'K097', 'K099', 'K101', 'K102', 'K104', 'K112', 'K121', 'K127', 'K128', 'K135', 'K139', 'K146', 'K152', 'K153', 'K165', 'K170', 'K172', 'K176', 'K177', 'K180', 'K181', 'K185', 'K186', 'K192', 'K200', 'K204', 'K205', 'K207', 'K209', 'K215', 'K216', 'K221', 'K222', 'K225', 'K226', 'K228', 'K229', 'K230', 'K234', 'K238', 'K245', 'K247', 'K249', 'K251', 'K255', 'K262', 'K277', 'K281', 'K289', 'K295', 'K306', 'K308', 'K318', 'K369', 'K370', 'K384', 'K394', 'K399', 'K405', 'K445', 'K485', 'K525', 'K535', 'K555', 'K685', 'K690', 'K721', 'K771', 'M001', 'M011', 'M036
M028', 'M034', 'M042', 'M050', 'M051', 'M052', 'M064', 'M075', 'M077', 'M087', 'M096', 'M104', 'M110', 'M115', 'M124', 'M126', 'M131', 'M132', 'M134', 'M140', 'M142', 'M143', 'M146', 'M158', 'M161', 'M183', 'M185', 'M197', 'M208', 'M223', 'M290', 'M409', 'M435', 'M505', 'M520', 'M550', 'M570', 'M580', 'M615', 'M625', 'M721', 'Q020', 'Q035', 'Q043', 'Q047', 'Q050', 'Q053', 'Q055', 'Q062', 'Q077', 'Q084', 'Q086', 'Q093', 'Q096', 'Q100', 'Q101', 'Q109', 'Q121', 'Q122', 'Q125', 'Q126', 'Q133', 'Q135', 'Q147', 'Q155', 'Q158', 'Q204', 'Q216', 'Q237', 'Q400', 'Q435', 'Q445', 'Q455', 'Q485', 'Q494', 'Q496', 'Q555', 'R052', 'X003', 'X015', 'X023', 'X025', 'X031', 'X042', 'X045', 'X046', 'X050', 'X051', 'X064', 'X070', 'X098', 'X112', 'X117', 'X118', 'X123', 'X125', 'X131', 'X132', 'X144', 'X162', 'X163', 'X175', 'X206', 'X219', 'X229', 'X230', 'X254', 'X277', 'X313', 'X390', 'X440', 'X600']
#
#
# Schools in cluster 3
# ['K002', 'K010', 'K012', 'K013', 'K014', 'K015', 'K016', 'K017', 'K018', 'K020', 'K023', 'K031', 'K032', 'K034', 'K038', 'K046', 'K051', 'K054', 'K058', 'K059', 'K067', 'K068', 'K081', 'K084', 'K094', 'K105', 'K106', 'K108', 'K110', 'K114', 'K115', 'K116', 'K119', 'K120', 'K123', 'K124', 'K132', 'K133', 'K147', 'K149', 'K151', 'K154', 'K155', 'K156', 'K158', 'K159', 'K160', 'K169', 'K187', 'K188', 'K189', 'K190', 'K191', 'K193', 'K194', 'K195', 'K196', 'K203', 'K211', 'K214', 'K219', 'K220', 'K223', 'K233', 'K239', 'K243', 'K250', 'K256', 'K261', 'K268', 'K270', 'K272', 'K273', 'K276', 'K279', 'K285', 'K287', 'K288', 'K290', 'K292', 'K297', 'K316', 'K321', 'K329', 'K345', 'K346', 'K364', 'K372', 'K575', 'M004', 'M007', 'M008', 'M009', 'M015', 'M019', 'M030', 'M033', 'M038', 'M040', 'M041', 'M048', 'M054', 'M063', 'M072', 'M083', 'M084', 'M098', 'M102', 'M108', 'M111', 'M112', 'M116', 'M125', 'M128', 'M137', 'M145', 'M152', 'M153', 'M154', 'M155', 'M163', 'M166', 'M173', 'M189', 'M192', 'M194', 'M206', 'M217', 'M218', 'M241', 'M243', 'M475', 'M528', 'M560', 'M600', 'M751', 'Q002', 'Q007', 'Q010', 'Q017', 'Q019', 'Q024', 'Q025', 'Q032', 'Q033', 'Q038', 'Q045', 'Q052', 'Q056', 'Q059', 'Q064', 'Q065', 'Q067', 'Q068', 'Q069', 'Q070', 'Q071', 'Q073', 'Q074', 'Q076', 'Q081', 'Q085', 'Q088', 'Q090', 'Q099', 'Q111', 'Q112', 'Q117', 'Q120', 'Q131', 'Q132', 'Q138', 'Q148', 'Q151', 'Q154', 'Q162', 'Q163', 'Q164', 'Q165', 'Q171', 'Q172', 'Q175', 'Q184', 'Q189', 'Q192', 'Q195', 'Q197', 'Q199', 'Q207', 'Q213', 'Q214', 'Q226', 'Q235', 'Q425', 'X001', 'X004', 'X006', 'X007', 'X009', 'X012', 'X018', 'X020', 'X022', 'X028', 'X030', 'X032', 'X043', 'X044', 'X048', 'X049', 'X053', 'X054', 'X055', 'X058', 'X059', 'X061', 'X065', 'X066', 'X067', 'X073', 'X075', 'X080', 'X088', 'X091', 'X092', 'X093', 'X095', 'X106', 'X107', 'X110', 'X111', 'X126', 'X127', 'X130', 'X134', 'X145', 'X154', 'X159', 'X160', 'X161', 'X178', 'X180', 'X207', 'X246', 'X306', 'X310', 'X445']
#
#
# Schools in cluster 4
# ['K035', 'K041', 'K044', 'K061', 'K071', 'K073', 'K096', 'K109', 'K113', 'K137', 'K141', 'K178', 'K235', 'K259', 'K267', 'K298', 'K305', 'K309', 'K311', 'K335', 'K381', 'K385', 'K397', 'K409', 'K410', 'K419', 'K425', 'K429', 'K439', 'K474', 'K477', 'K478', 'K490', 'K498', 'K499', 'K505', 'K545', 'K590', 'K615', 'K670', 'K811', 'M003', 'M006', 'M018', 'M035', 'M059', 'M079', 'M130', 'M149', 'M167', 'M191', 'M198', 'M200', 'M245', 'M250', 'M256', 'M258', 'M289', 'M333', 'M407', 'M415', 'M419', 'M448', 'M459', 'M462', 'M463', 'M467', 'M468', 'M469', 'M499', 'M509', 'M540', 'M630', 'M650', 'M655', 'M670', 'M680', 'M685', 'M811', 'Q008', 'Q018', 'Q023', 'Q042', 'Q072', 'Q119', 'Q150', 'Q153', 'Q156', 'Q188', 'Q202', 'Q210', 'Q238', 'Q430', 'Q450', 'Q460', 'Q475', 'Q480', 'Q499', 'Q550', 'Q610', 'Q620', 'R007', 'R016', 'R021', 'R072', 'R445', 'X021', 'X062', 'X085', 'X096', 'X101', 'X105', 'X146', 'X151', 'X211', 'X212', 'X236', 'X339', 'X391', 'X405', 'X455', 'X480', 'X500', 'X520', 'X530', 'X550', 'X670', 'X682', 'X684', 'X692', 'X695']

# %% [markdown]
# _____________________

# %% [markdown]
# ## ELL's student enrolment - ONLY TWO YEARS OF DATA AVAILABLE. IGNORE
#
# _________

# %% [markdown]
# ## Special Ed student enrolment

# %%
tsSpEdEnrolment = f1[f1['variable']=='ENRNUMSPD']

# %%
tsSpEdEnrolment.head()
# Out:
#     BNLONG   variable 1996 1997 1998 1999 2000 2001 2002 2003 ...  2007 2008  \
# 84    K001  ENRNUMSPD   50   51   26   25   18   22   34   25 ...    68   83
# 230   K002  ENRNUMSPD   29   42   45   61   62   70   79  101 ...   101  101
# 376   K003  ENRNUMSPD   21   25   17   17   18   18   19   18 ...    22   22
# 522   K004  ENRNUMSPD  232  228  255  255  235  250  242  240 ...   301  276
# 668   K005  ENRNUMSPD   21    9   50   51   47   47   38   39 ...    39   40
#
#     2009 2010 2011 2012 2013 2014 2015 2016
# 84    94   96  113  101  109  116  140  168
# 230   86   68   60   54   44   47   54   57
# 376   21   28   26   34   39   37   29   32
# 522  308  332  344  363  369  365  344  339
# 668   34   28   40   47   37   29   22   31
#
# [5 rows x 23 columns]

# %%
# new dictionary colUpdate with all column names as strings
colUpdate = { 1996 : u'1996',       
              1997 : u'1997',       
              1998 : u'1998',       
              1999 : u'1999',
              2000 : u'2000',
              2001 : u'2001',     
              2002 : u'2002',
              2003 : u'2003',     
              2004 : u'2004',
              2005 : u'2005',
              2006 : u'2006',
              2007 : u'2007',     
              2008 : u'2008',
              2009 : u'2009',     
              2010 : u'2010',
              2011 : u'2011',
              2012 : u'2012',
              2013 : u'2013', 
              2014 : u'2014',
              2015 : u'2015',
              2016 : u'2016'}
tsSpEdEnrolment.rename(columns = colUpdate, inplace=True)
tsSpEdEnrolment.columns
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\pandas\core\frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# Index(['BNLONG', 'variable', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')

# %%
## Remove columns where all NaN
tsSpEdEnrolment.dropna(axis=1, how='all', inplace=True)
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## Remove rows where any NaN
tsSpEdEnrolment.dropna(axis=0, how='any',inplace=True)
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tsSpEdEnrolment.shape
# Out:
# (900, 23)

# %%
tsSpEdEnrolment = tsSpEdEnrolment.loc[(tsSpEdEnrolment.loc[:,'1996':]!=0).any(axis=1)]

# %%
tsSpEdEnrolment.shape
# Out:
# (892, 23)

# %%
tsSpEdEnrolment.head()
# Out:
#     BNLONG   variable 1996 1997 1998 1999 2000 2001 2002 2003 ...  2007 2008  \
# 84    K001  ENRNUMSPD   50   51   26   25   18   22   34   25 ...    68   83
# 230   K002  ENRNUMSPD   29   42   45   61   62   70   79  101 ...   101  101
# 376   K003  ENRNUMSPD   21   25   17   17   18   18   19   18 ...    22   22
# 522   K004  ENRNUMSPD  232  228  255  255  235  250  242  240 ...   301  276
# 668   K005  ENRNUMSPD   21    9   50   51   47   47   38   39 ...    39   40
#
#     2009 2010 2011 2012 2013 2014 2015 2016
# 84    94   96  113  101  109  116  140  168
# 230   86   68   60   54   44   47   54   57
# 376   21   28   26   34   39   37   29   32
# 522  308  332  344  363  369  365  344  339
# 668   34   28   40   47   37   29   22   31
#
# [5 rows x 23 columns]

# %%
tsSpEdEnrolment['popmean'] = tsSpEdEnrolment['2016']
tsSpEdEnrolment['stdev'] = tsSpEdEnrolment['2016']
tsSpEdEnrolment.head()
# Out:
#     BNLONG   variable 1996 1997 1998 1999 2000 2001 2002 2003  ...  2009 2010  \
# 84    K001  ENRNUMSPD   50   51   26   25   18   22   34   25  ...    94   96
# 230   K002  ENRNUMSPD   29   42   45   61   62   70   79  101  ...    86   68
# 376   K003  ENRNUMSPD   21   25   17   17   18   18   19   18  ...    21   28
# 522   K004  ENRNUMSPD  232  228  255  255  235  250  242  240  ...   308  332
# 668   K005  ENRNUMSPD   21    9   50   51   47   47   38   39  ...    34   28
#
#     2011 2012 2013 2014 2015 2016 popmean stdev
# 84   113  101  109  116  140  168     168   168
# 230   60   54   44   47   54   57      57    57
# 376   26   34   39   37   29   32      32    32
# 522  344  363  369  365  344  339     339   339
# 668   40   47   37   29   22   31      31    31
#
# [5 rows x 25 columns]

# %%
# append on mean and standard deviation to the datasets (BRUTE FORCE)

# Calculate the mean and standard deviation of the school totals over time
## in preparation for clustering
tsSpEdEnrolment['popmean'] = tsSpEdEnrolment['2016']
tsSpEdEnrolment['stdev'] = tsSpEdEnrolment['2016']

for i in tsSpEdEnrolment.index:
    tsSpEdEnrolment['popmean'].loc[i] = tsSpEdEnrolment.loc[i].drop(['BNLONG', 'variable','popmean','stdev']).mean() 
    tsSpEdEnrolment['stdev'].loc[i] = tsSpEdEnrolment.loc[i].drop(['BNLONG', 'variable','popmean','stdev']).std()

# %%
tsSpEdEnrolment.head()
# Out:
#     BNLONG   variable 1996 1997 1998 1999 2000 2001 2002 2003   ...    2009  \
# 84    K001  ENRNUMSPD   50   51   26   25   18   22   34   25   ...      94
# 230   K002  ENRNUMSPD   29   42   45   61   62   70   79  101   ...      86
# 376   K003  ENRNUMSPD   21   25   17   17   18   18   19   18   ...      21
# 522   K004  ENRNUMSPD  232  228  255  255  235  250  242  240   ...     308
# 668   K005  ENRNUMSPD   21    9   50   51   47   47   38   39   ...      34
#
#     2010 2011 2012 2013 2014 2015 2016  popmean    stdev
# 84    96  113  101  109  116  140  168  71.1429  43.0096
# 230   68   60   54   44   47   54   57  67.6667  21.6849
# 376   28   26   34   39   37   29   32  24.1905  6.65296
# 522  332  344  363  369  365  344  339   290.81  49.5809
# 668   28   40   47   37   29   22   31  35.0476  11.8426
#
# [5 rows x 25 columns]

# %%
tsSpEdEnrolment.shape
# Out:
# (892, 25)

# %%
## Standardise the data

tsSpEdEnrolment.columns
# Out:
# Index(['BNLONG', 'variable', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', 'popmean', 'stdev'],
#       dtype='object')

# %%
tsSpEdEnrolStandard = tsSpEdEnrolment.copy()
columnsStandard = ['1996', '1997', '1998', '1999', '2000', '2001',
       '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
       '2011', '2012', '2013', '2014', '2015', '2016',]

# %%
for i in columnsStandard:
    tsSpEdEnrolStandard[i] = (tsSpEdEnrolment[i] - tsSpEdEnrolment.popmean) / tsSpEdEnrolment.stdev

# %%
tsSpEdEnrolStandard.columns
# Out:
# Index(['BNLONG', 'variable', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', 'popmean', 'stdev'],
#       dtype='object')

# %%
vals = tsSpEdEnrolStandard.drop(['BNLONG', 'variable', 'popmean', 'stdev'], axis = 1)

# %%
# Check if as expected, means are zero and standard devations are 1

print("Expect means of each row to be = 0\n", vals.mean(1)[:10])
print("Expect stds of each row to be = 1\n", vals.std(1)[:10])
# Out:
# Expect means of each row to be = 0
#  84      1.268826e-16
# 230    -2.220446e-16
# 376     1.057355e-16
# 522     2.273314e-16
# 668    -2.590520e-16
# 814    -4.229421e-17
# 960     2.114711e-17
# 1106    4.229421e-17
# 1252    2.749124e-16
# 1398   -2.749124e-16
# dtype: float64
# Expect stds of each row to be = 1
#  84      1.0
# 230     1.0
# 376     1.0
# 522     1.0
# 668     1.0
# 814     1.0
# 960     1.0
# 1106    1.0
# 1252    1.0
# 1398    1.0
# dtype: float64

# %%
## Remove rows where any NaN (some rows were all zeroes)
vals.dropna(axis=0, how='any',inplace=True)

# %%
vals.head()
# Out:
#          1996      1997      1998      1999      2000      2001      2002  \
# 84  -0.491584 -0.468334   -1.0496  -1.07285   -1.2356   -1.1426 -0.863594
# 230  -1.78312  -1.18362  -1.04528 -0.307434 -0.261319  0.107602  0.522638
# 376 -0.479557  0.121679  -1.08079  -1.08079 -0.930484 -0.930484 -0.780175
# 522  -1.18613  -1.26681 -0.722245 -0.722245  -1.12563  -0.82309 -0.984443
# 668  -1.18619  -2.19948   1.26259   1.34703   1.00927   1.00927  0.249301
#
#          2003       2004      2005    ...          2007      2008       2009  \
# 84   -1.07285  -0.817093 -0.514835    ...    -0.0730733  0.275686   0.531442
# 230   1.53717    1.16825  0.292062    ...       1.53717   1.53717   0.845444
# 376 -0.930484 -0.0286303 -0.479557    ...     -0.329248 -0.329248  -0.479557
# 522  -1.02478  -0.964274  0.124856    ...      0.205532 -0.298694   0.346716
# 668  0.333742   -2.11504  0.164861    ...      0.333742  0.418183 -0.0884618
#
#           2010      2011      2012      2013      2014      2015      2016
# 84    0.577944  0.973204  0.694197  0.880201   1.04296   1.60097   2.25199
# 230  0.0153717 -0.353549  -0.63024  -1.09139 -0.953046  -0.63024 -0.491895
# 376   0.572606  0.271988   1.47446     2.226   1.92539  0.722915   1.17384
# 522   0.830774    1.0728   1.45601   1.57703   1.49635    1.0728  0.971957
# 668  -0.595106  0.418183   1.00927  0.164861 -0.510666  -1.10175 -0.341784
#
# [5 rows x 21 columns]

# %%
elbow(vals, range(1,26))

# %%
###############################################################################
# Fit K-means algorithm for selected number of clusters (again)


#creating a date range: 2000-2016
timeline = pd.date_range('1996', '2017', freq='A')

nc = 5

km = KMeans(n_clusters=nc, random_state=888)

km.fit(vals)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=888, tol=0.0001, verbose=0)

# %%
fig = pl.figure(figsize=(12, 8))
for i, Xc in enumerate(km.cluster_centers_):
    ax = fig.add_subplot(3, 2, (i + 1))
    ax.plot(timeline, Xc, lw = 8, alpha = 0.5, c='IndianRed')
    
    pl.title("Cluster centre %d"%(i), fontsize = 16)
    
    
    pl.xticks(fontsize = 15, rotation=75)
    ax.set_yticklabels(['' * len(ax.get_xticklabels())])
    plt.tight_layout()
print("Cluster centers")
# Out:
# Cluster centers

# %%
tsSpEdEnrolStandard['ClustLabel'] = km.labels_

# %%
tsSpEdEnrolStandard.columns
# Out:
# Index(['BNLONG', 'variable', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', 'popmean', 'stdev',
#        'ClustLabel'],
#       dtype='object')

# %%
vals = tsSpEdEnrolStandard.drop(['variable', 'popmean', 'stdev'], axis = 1)

# %%
for j in range(nc):
    print("Schools in cluster", j)
    print(list(vals.BNLONG[km.labels_ == j]))
    print("\n")
# Out:
# Schools in cluster 0
#
#
# Schools in cluster 1
# ['K012', 'K016', 'K025', 'K026', 'K035', 'K038', 'K040', 'K045', 'K052', 'K054', 'K056', 'K059', 'K067', 'K073', 'K084', 'K147', 'K150', 'K167', 'K174', 'K190', 'K191', 'K192', 'K196', 'K197', 'K201', 'K202', 'K208', 'K211', 'K216', 'K218', 'K238', 'K255', 'K256', 'K262', 'K270', 'K272', 'K274', 'K279', 'K287', 'K291', 'K292', 'K297', 'K299', 'K306', 'K312', 'K328', 'K335', 'K377', 'K384', 'K575', 'K605', 'K610', 'K753', 'M015', 'M030', 'M033', 'M052', 'M054', 'M092', 'M125', 'M128', 'M132', 'M134', 'M143', 'M153', 'M192', 'M199', 'M485', 'M550', 'M560', 'M600', 'M721', 'M751', 'Q037', 'Q045', 'Q067', 'Q071', 'Q101', 'Q111', 'Q115', 'Q118', 'Q126', 'Q134', 'Q141', 'Q144', 'Q146', 'Q156', 'Q158', 'Q163', 'Q169', 'Q171', 'Q201', 'Q202', 'Q203', 'Q204', 'Q207', 'Q213', 'Q223', 'Q232', 'Q237', 'Q455', 'Q485', 'R470', 'X004', 'X007', 'X012', 'X022', 'X024', 'X037', 'X042', 'X044', 'X055', 'X057', 'X059', 'X061', 'X063', 'X067', 'X107', 'X110', 'X111', 'X121', 'X132', 'X134', 'X140', 'X141', 'X145', 'X146', 'X153', 'X154', 'X160', 'X161', 'X162', 'X175', 'X178', 'X180', 'X306']
#
#
# Schools in cluster 2
# ['K009', 'K013', 'K020', 'K088', 'K092', 'K101', 'K107', 'K112', 'K121', 'K132', 'K154', 'K157', 'K158', 'K162', 'K163', 'K176', 'K184', 'K187', 'K189', 'K206', 'K213', 'K219', 'K220', 'K226', 'K228', 'K231', 'K239', 'K257', 'K265', 'K281', 'K282', 'K303', 'K318', 'K321', 'K346', 'K380', 'K383', 'K405', 'K555', 'K590', 'M007', 'M009', 'M018', 'M019', 'M063', 'M084', 'M094', 'M098', 'M108', 'M154', 'M161', 'M166', 'M169', 'M173', 'M180', 'M191', 'M206', 'M407', 'M408', 'M505', 'M519', 'M528', 'M531', 'M540', 'M630', 'Q031', 'Q036', 'Q040', 'Q048', 'Q061', 'Q063', 'Q077', 'Q093', 'Q094', 'Q098', 'Q104', 'Q105', 'Q128', 'Q132', 'Q138', 'Q140', 'Q154', 'Q157', 'Q159', 'Q162', 'Q172', 'Q176', 'Q183', 'Q185', 'Q188', 'Q191', 'Q227', 'Q238', 'Q505', 'Q555', 'Q610', 'Q680', 'R005', 'R008', 'R048', 'R050', 'X005', 'X018', 'X019', 'X025', 'X029', 'X032', 'X066', 'X068', 'X078', 'X081', 'X089', 'X095', 'X108', 'X117', 'X118', 'X129', 'X157', 'X181']
#
#
# Schools in cluster 3
